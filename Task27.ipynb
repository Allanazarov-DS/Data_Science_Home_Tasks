# %%
import pandas as pd
import math
import numpy as np
from manual_metrics import mean_squared_error_manual as msem

# %%
# Mean Squared Error
def mean_squared_error_manual(y_true, y_pred):
    return sum((y - y_hat) ** 2 for y, y_hat in zip(y_true, y_pred)) / len(y_true)

# Root Mean Squared Error
def root_mean_squared_error_manual(y_true, y_pred):
    mse = mean_squared_error_manual(y_true, y_pred)
    return math.sqrt(mse)

# %%
df = pd.read_csv('car_prices.csv', index_col=0)
df.head(3)
# Out:
#      brand         model  model_year  milage fuel_type  \
# id
# 0     Ford  F-150 Lariat        2018   74349  Gasoline
# 1      BMW         335 i        2007   80000  Gasoline
# 2   Jaguar     XF Luxury        2009   91491  Gasoline
#
#                                                engine  transmission ext_col  \
# id
# 0       375.0HP 3.5L V6 Cylinder Engine Gasoline Fuel  10-Speed A/T    Blue
# 1   300.0HP 3.0L Straight 6 Cylinder Engine Gasoli...   6-Speed M/T   Black
# 2        300.0HP 4.2L 8 Cylinder Engine Gasoline Fuel   6-Speed A/T  Purple
#
#    int_col       accident clean_title  price
# id
# 0     Gray  None reported         Yes  11000
# 1    Black  None reported         Yes   8250
# 2    Beige  None reported         Yes  15000

# %%
df = df.drop('clean_title', axis = 1)

# %%
df.head()
# Out:
#       brand          model  model_year  milage fuel_type  \
# id
# 0      Ford   F-150 Lariat        2018   74349  Gasoline
# 1       BMW          335 i        2007   80000  Gasoline
# 2    Jaguar      XF Luxury        2009   91491  Gasoline
# 3       BMW   X7 xDrive40i        2022    2437    Hybrid
# 4   Pontiac  Firebird Base        2001  111000  Gasoline
#
#                                                engine  \
# id
# 0       375.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 1   300.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2        300.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 3   335.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 4       200.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
#
#                       transmission ext_col int_col       accident  price
# id
# 0                     10-Speed A/T    Blue    Gray  None reported  11000
# 1                      6-Speed M/T   Black   Black  None reported   8250
# 2                      6-Speed A/T  Purple   Beige  None reported  15000
# 3   Transmission w/Dual Shift Mode    Gray   Brown  None reported  63500
# 4                              A/T   White   Black  None reported   7850

# %%
df.shape
# Out:
# (54273, 11)

# %%
df['Horse_power'] = [item.split('.0HP')[0] for item in df['engine']]

# %%
# df[df['Horse_power'] >

# %%
df['Horse_power'] = df['Horse_power'].apply(lambda x: int(x) if x.isdigit() else np.nan)

# %%
df['Horse_power'].isna().sum()
# Out:
# np.int64(4057)

# %%
# mini = df.sample(1000)
# mini.to_csv("cars_mini2.csv")

# %%
df.head(3)
# Out:
#      brand         model  model_year  milage fuel_type  \
# id
# 0     Ford  F-150 Lariat        2018   74349  Gasoline
# 1      BMW         335 i        2007   80000  Gasoline
# 2   Jaguar     XF Luxury        2009   91491  Gasoline
#
#                                                engine  transmission ext_col  \
# id
# 0       375.0HP 3.5L V6 Cylinder Engine Gasoline Fuel  10-Speed A/T    Blue
# 1   300.0HP 3.0L Straight 6 Cylinder Engine Gasoli...   6-Speed M/T   Black
# 2        300.0HP 4.2L 8 Cylinder Engine Gasoline Fuel   6-Speed A/T  Purple
#
#    int_col       accident  price  Horse_power
# id
# 0     Gray  None reported  11000        375.0
# 1    Black  None reported   8250        300.0
# 2    Beige  None reported  15000        300.0

# %%
df['milage_per_year'] = df['milage'] / (2024 - df['model_year'])

# %%
df.head(3)
# Out:
#      brand         model  model_year  milage fuel_type  \
# id
# 0     Ford  F-150 Lariat        2018   74349  Gasoline
# 1      BMW         335 i        2007   80000  Gasoline
# 2   Jaguar     XF Luxury        2009   91491  Gasoline
#
#                                                engine  transmission ext_col  \
# id
# 0       375.0HP 3.5L V6 Cylinder Engine Gasoline Fuel  10-Speed A/T    Blue
# 1   300.0HP 3.0L Straight 6 Cylinder Engine Gasoli...   6-Speed M/T   Black
# 2        300.0HP 4.2L 8 Cylinder Engine Gasoline Fuel   6-Speed A/T  Purple
#
#    int_col       accident  price  Horse_power  milage_per_year
# id
# 0     Gray  None reported  11000        375.0     12391.500000
# 1    Black  None reported   8250        300.0      4705.882353
# 2    Beige  None reported  15000        300.0      6099.400000

# %%
milage_bins = [df['milage'].min(), df['milage'].quantile(1/3), df['milage'].quantile(2/3), df['milage'].max()]
price_bins = [df['price'].min(), df['price'].quantile(1/3), df['price'].quantile(2/3), df['price'].max()]

bin_labels = ['Low', 'Medium', 'High']

df['milage_bins'] = pd.cut(df['milage'], bins = milage_bins, labels=bin_labels, include_lowest=True)

# %%
# df[['milage', 'milage_bin']]

# %%
df['price_bins'] = pd.cut(df['price'], bins = price_bins, labels=bin_labels, include_lowest=True)

# %%
df.sample(10)
# Out:
#                brand                      model  model_year  milage fuel_type  \
# id
# 24914      Chevrolet    Corvette Stingray w/1LT        2023    4200  Gasoline
# 48201            BMW                   X5 3.0si        2004  110000  Gasoline
# 10929  Mercedes-Benz       AMG E 53 Base 4MATIC        2022   13000    Hybrid
# 20041           Ford         Mustang GT Premium        2019   50000  Gasoline
# 2896          Toyota                4Runner SR5        2019  101900  Gasoline
# 39528          Aston        Martin Vantage Base        2022    3000  Gasoline
# 26550            Kia              Forte GT-Line        2022   14950  Gasoline
# 23833           Audi  S3 2.0T Tech Premium Plus        2018   42200  Gasoline
# 50888            BMW                    M3 Base        2012  148000  Gasoline
# 22826            BMW                    M3 Base        2015   10950  Gasoline
#
#                                                   engine  \
# id
# 24914       490.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 48201  260.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 10929  429.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 20041       460.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 2896       270.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 39528       503.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 26550       147.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 23833       292.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 50888  333.0HP 3.2L Straight 6 Cylinder Engine Gasoli...
# 22826  425.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
#
#                          transmission ext_col int_col  \
# id
# 24914                     8-Speed A/T   White     Red
# 48201                     6-Speed A/T  Silver    Gray
# 10929                     9-Speed A/T    Gray   White
# 20041                     6-Speed M/T   White   Black
# 2896                              A/T   Black   Black
# 39528                     8-Speed A/T    Gray   Brown
# 26550                             A/T  Purple   Black
# 23833  Transmission w/Dual Shift Mode    Blue   Black
# 50888                             A/T   Black   Black
# 22826                             M/T   White   Black
#
#                                      accident  price  Horse_power  \
# id
# 24914                           None reported  72999        490.0
# 48201                           None reported   8500        260.0
# 10929                           None reported  81500        429.0
# 20041                           None reported  37700        460.0
# 2896                            None reported  28000        270.0
# 39528                           None reported  87000        503.0
# 26550  At least 1 accident or damage reported   8995        147.0
# 23833                           None reported  42800        292.0
# 50888  At least 1 accident or damage reported  10000        333.0
# 22826                           None reported  83999        425.0
#
#        milage_per_year milage_bins price_bins
# id
# 24914      4200.000000         Low       High
# 48201      5500.000000        High        Low
# 10929      6500.000000         Low       High
# 20041     10000.000000      Medium     Medium
# 2896      20380.000000        High     Medium
# 39528      1500.000000         Low       High
# 26550      7475.000000         Low        Low
# 23833      7033.333333         Low       High
# 50888     12333.333333        High        Low
# 22826      1216.666667         Low       High
