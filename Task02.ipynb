# %%
import pandas as pd
from pandas import Series
import numbers

# %%
df = pd.read_csv('1000 Sales Records.csv')
df
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %% [markdown]
# ### Filterlashdan foydalanib kordim

# %%
# filtered_df = df[df['Unit Price'] < 200] # - Unit price 200dan kichiklarni saraladim
# filtered_df = df[df['Country'] == 'Japan'] # - Mamlakat Yaponiya bo'lganlarni chiqarib ko'rdim
# df['Sales Channel'] # Series ko'rinishida chiqarib ko'rdim


############################ Offline va Online sotuv kanllarini offline yoki online tekshirdim ####################
# filtered_df = df[df['Sales Channel'] == 'Offline']
# filtered_df = df[df['Sales Channel'] == 'Online']

# countries_df = df['Country']
# check_unique = countries_df.drop_duplicates().head(20) # - duplicat holatda 20ta davlatni example uchun o'zgaruvchiga oldim 
# check_unique.unique # - Yagona ekanligini tekshirdim

# %% [markdown]
# ### DataFrameni ixchamladim 100x5 formatda

# %%
df2 = df.iloc[0:100, 0:5]
df2
# Out:
#                           Region     Country   Item Type Sales Channel  \
# 0   Middle East and North Africa       Libya   Cosmetics       Offline
# 1                  North America      Canada  Vegetables        Online
# 2   Middle East and North Africa       Libya   Baby Food       Offline
# 3                           Asia       Japan      Cereal       Offline
# 4             Sub-Saharan Africa        Chad      Fruits       Offline
# ..                           ...         ...         ...           ...
# 95         Australia and Oceania      Tuvalu      Snacks       Offline
# 96            Sub-Saharan Africa       Sudan      Fruits        Online
# 97            Sub-Saharan Africa       Niger     Clothes        Online
# 98            Sub-Saharan Africa       Gabon   Household       Offline
# 99         Australia and Oceania  East Timor  Vegetables       Offline
#
#    Order Priority
# 0               M
# 1               M
# 2               C
# 3               C
# ...

# %% [markdown]
# ### Ixchamlangan dataframedan 'Item type'i 'Vegetables' va Osiyoda joylashgan davlatlarni ajratdim

# %%
df2[(df2['Item Type'] == 'Vegetables') & (df2['Region']  == 'Asia')]
# Va natijada faqat bitta davlat chiqdi
# Out:
#    Region Country   Item Type Sales Channel Order Priority
# 58   Asia   Nepal  Vegetables       Offline              C

# %%
df[(df['Region'] == 'Asia') & (df['Item Type'] == 'Vegetables')] # - Butun dunyo bo'ylab ham ajratib oldim
# Out:
#     Region     Country   Item Type Sales Channel Order Priority  Order Date  \
# 58    Asia       Nepal  Vegetables       Offline              C    6/2/2014
# 252   Asia    Maldives  Vegetables        Online              H   2/25/2015
# 331   Asia       China  Vegetables        Online              H    9/5/2010
# 370   Asia    Mongolia  Vegetables        Online              C  11/27/2010
# 417   Asia  Tajikistan  Vegetables        Online              H   8/21/2014
# 527   Asia  Kyrgyzstan  Vegetables        Online              H    3/7/2011
# 648   Asia     Vietnam  Vegetables       Offline              M   2/18/2016
# 771   Asia    Maldives  Vegetables       Offline              M   1/11/2014
# 821   Asia  Kyrgyzstan  Vegetables       Offline              H   1/29/2017
# 827   Asia    Thailand  Vegetables        Online              L   7/17/2010
# 913   Asia     Myanmar  Vegetables       Offline              L   1/14/2013
#
# ...

# %% [markdown]
# ### Va yana bazi boshqa amallarni ham bu dataframe ustida amalga oshirib kordim

# %%
items = df.drop_duplicates(subset='Item Type')
items['Item Type']
items = pd.Series(items['Item Type'])
arr = items.values
for x in arr:
    print(x)
# Out:
# Cosmetics
# Vegetables
# Baby Food
# Cereal
# Fruits
# Clothes
# Snacks
# Household
# Office Supplies
# Beverages
# Personal Care
# Meat
