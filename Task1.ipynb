# %% [markdown]
# ## Read csv file using pandas

# %%
# import libraries
import pandas as pd

# %%
# read csv file using pandas
df = pd.read_csv("Football_teams_price_data.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # read csv file using pandas
# ----> 2 df = pd.read_csv("Football_teams_price_data.csv")
#       3 df
#
# ...

# %% [markdown]
# ## Usage of methods in pandas

# %%
# head()
df.head()
# Out:
#    AveragePlayerAge  TotalGoalsLastSeason  MatchesWonLastSeason  \
# 0         24.367182                    28                    16
# 1         34.162143                    89                    12
# 2         30.443897                    43                     3
# 3         28.177194                    84                    19
# 4         20.652317                    36                    36
#
#    MatchesDrawnLastSeason  MatchesLostLastSeason  \
# 0                      36                     20
# 1                      35                     31
# 2                       9                     28
# 3                      19                     34
# 4                      10                      9
#
#    TotalGoalsConcededLastSeason  TotalRevenueLastSeason  StadiumCapacity  \
# 0                            51              337.552001            55766
# 1                            84              264.850402            15307
# ...

# %%
# head() usage with argument
df.head(10)
# Out:
#    AveragePlayerAge  TotalGoalsLastSeason  MatchesWonLastSeason  \
# 0         24.367182                    28                    16
# 1         34.162143                    89                    12
# 2         30.443897                    43                     3
# 3         28.177194                    84                    19
# 4         20.652317                    36                    36
# 5         20.651907                    56                    14
# 6         18.987421                    69                    34
# 7         32.724994                    64                    22
# 8         28.218955                    39                    30
# 9         30.037234                    78                    14
#
#    MatchesDrawnLastSeason  MatchesLostLastSeason  \
# 0                      36                     20
# 1                      35                     31
# 2                       9                     28
# 3                      19                     34
# ...

# %%
# info method
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   AveragePlayerAge              50000 non-null  float64
#  1   TotalGoalsLastSeason          50000 non-null  int64
#  2   MatchesWonLastSeason          50000 non-null  int64
#  3   MatchesDrawnLastSeason        50000 non-null  int64
#  4   MatchesLostLastSeason         50000 non-null  int64
#  5   TotalGoalsConcededLastSeason  50000 non-null  int64
#  6   TotalRevenueLastSeason        50000 non-null  float64
#  7   StadiumCapacity               50000 non-null  int64
#  8   AverageAttendance             50000 non-null  float64
#  9   TransferSpendingLastSeason    50000 non-null  float64
#  10  TransferIncomeLastSeason      50000 non-null  float64
#  11  NumberOfTrophies              50000 non-null  int64
# ...

# %%
# describe()
df.describe()
# Out:
#        AveragePlayerAge  TotalGoalsLastSeason  MatchesWonLastSeason  \
# count      50000.000000          50000.000000          50000.000000
# mean          26.480678             59.343160             18.425460
# std            4.902909             23.095732             10.955441
# min           18.000094             20.000000              0.000000
# 25%           22.231468             39.000000              9.000000
# 50%           26.481162             59.000000             18.000000
# 75%           30.721124             79.000000             28.000000
# max           34.999527             99.000000             37.000000
#
#        MatchesDrawnLastSeason  MatchesLostLastSeason  \
# count            50000.000000           50000.000000
# mean                18.604460              18.478100
# std                 10.980261              10.996911
# min                  0.000000               0.000000
# 25%                  9.000000               9.000000
# ...

# %%
# shape
df.shape
# Out:
# (50000, 26)

# %%
df.values
# Out:
# array([[24.367182020405163, 28, 16, ..., 'Manufacturer B', 'Private',
#         '4,375,181,628'],
#        [34.16214320896857, 89, 12, ..., 'Manufacturer B', 'Consortium',
#         '859,750,388'],
#        [30.443897010793886, 43, 3, ..., 'Manufacturer C', 'Consortium',
#         '2,168,913,729'],
#        ...,
#        [30.732916439297604, 88, 34, ..., 'Manufacturer A', 'Private',
#         '4,884,297,718'],
#        [26.85718550156197, 78, 22, ..., 'Manufacturer A', 'Private',
#         '3,060,046,918'],
#        [32.64901407711477, 61, 28, ..., 'Manufacturer C', 'Public',
#         '3,633,930,225']], dtype=object)

# %%
# sorting methods
df.sort_index()
# Out:
#        AveragePlayerAge  TotalGoalsLastSeason  MatchesWonLastSeason  \
# 0             24.367182                    28                    16
# 1             34.162143                    89                    12
# 2             30.443897                    43                     3
# 3             28.177194                    84                    19
# 4             20.652317                    36                    36
# ...                 ...                   ...                   ...
# 49995         28.581568                    93                    27
# 49996         21.845291                    93                    20
# 49997         30.732916                    88                    34
# 49998         26.857186                    78                    22
# 49999         32.649014                    61                    28
#
#        MatchesDrawnLastSeason  MatchesLostLastSeason  \
# 0                          36                     20
# ...

# %%
df.sort_values
# Out:
# <bound method DataFrame.sort_values of        AveragePlayerAge  TotalGoalsLastSeason  MatchesWonLastSeason  \
# 0             24.367182                    28                    16
# 1             34.162143                    89                    12
# 2             30.443897                    43                     3
# 3             28.177194                    84                    19
# 4             20.652317                    36                    36
# ...                 ...                   ...                   ...
# 49995         28.581568                    93                    27
# 49996         21.845291                    93                    20
# 49997         30.732916                    88                    34
# 49998         26.857186                    78                    22
# 49999         32.649014                    61                    28
#
#        MatchesDrawnLastSeason  MatchesLostLastSeason  \
# 0                          36                     20
# ...

# %%
# directly usage of sort_values() method
df.sort_values("AveragePlayerAge")
# Out:
#        AveragePlayerAge  TotalGoalsLastSeason  MatchesWonLastSeason  \
# 33726         18.000094                    25                     9
# 2902          18.000198                    91                    13
# 42631         18.000285                    54                    36
# 4151          18.000522                    36                     1
# 21945         18.000818                    30                     4
# ...                 ...                   ...                   ...
# 41322         34.998140                    81                    35
# 21043         34.998317                    37                     3
# 15618         34.998722                    36                    25
# 46862         34.999268                    71                    19
# 43676         34.999527                    44                     0
#
#        MatchesDrawnLastSeason  MatchesLostLastSeason  \
# 33726                      24                     28
# ...

# %% [markdown]
# ## Other operations these I learnt

# %%
# taking specific column
df["AveragePlayerAge"]
# Out:
# 0        24.367182
# 1        34.162143
# 2        30.443897
# 3        28.177194
# 4        20.652317
#            ...
# 49995    28.581568
# 49996    21.845291
# 49997    30.732916
# 49998    26.857186
# 49999    32.649014
# Name: AveragePlayerAge, Length: 50000, dtype: float64

# %%
# taking multiple columns
df[["TotalGoalsLastSeason", "AveragePlayerAge"]]
# Out:
#        TotalGoalsLastSeason  AveragePlayerAge
# 0                        28         24.367182
# 1                        89         34.162143
# 2                        43         30.443897
# 3                        84         28.177194
# 4                        36         20.652317
# ...                     ...               ...
# 49995                    93         28.581568
# 49996                    93         21.845291
# 49997                    88         30.732916
# 49998                    78         26.857186
# 49999                    61         32.649014
#
# [50000 rows x 2 columns]
