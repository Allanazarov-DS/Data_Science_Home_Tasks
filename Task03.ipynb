# %%
import pandas as pd

# %%
df = pd.read_csv("100 Sales Records.csv")

# %% [markdown]
# ### Region ustunini index qilib olmoqchiman

# %%
df.set_index('Region')
# Out:
#                                                  Country        Item Type  \
# Region
# Australia and Oceania                             Tuvalu        Baby Food
# Central America and the Caribbean                Grenada           Cereal
# Europe                                            Russia  Office Supplies
# Sub-Saharan Africa                 Sao Tome and Principe           Fruits
# Sub-Saharan Africa                                Rwanda  Office Supplies
# ...                                                  ...              ...
# Sub-Saharan Africa                                  Mali          Clothes
# Asia                                            Malaysia           Fruits
# Sub-Saharan Africa                          Sierra Leone       Vegetables
# North America                                     Mexico    Personal Care
# Sub-Saharan Africa                            Mozambique        Household
#
# ...

# %% [markdown]
# ### Region ustunini index qilib oldim set_index() metodi yordamida

# %% [markdown]
# ### Endi reset_index() metodi yordamida eski indexni qaytarib ko'rmoqchiman

# %%
df.reset_index(drop = True)
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %% [markdown]
# ### Natijada eski indexlarni qaytarib oldim

# %% [markdown]
# ### 'Country' ustunida O'zbekiton va Qozog'iston bormi yo'qmi tekshirmoqchiman

# %%
df[df["Country"].isin(['Uzbekistan', 'Kazakhstan'])]
# Out:
# Empty DataFrame
# Columns: [Region, Country, Item Type, Sales Channel, Order Priority, Order Date, Order ID, Ship Date, Units Sold, Unit Price, Unit Cost, Total Revenue, Total Cost, Total Profit]
# Index: []

# %% [markdown]
# ### O'zbekiston va Qozog'iston bo'lmagani uchun ustunlarni shunchaki bo'sh holatda qaytardi xatolik bermadi

# %% [markdown]
# ### Endi esa 'Country' ustunida mavjud bo'lgan davlatlarni isin() metodining ichiga berib ko'ramiz

# %%
df[df['Country'].isin(['Mexico', 'Malaysia'])]
# Out:
#            Region   Country      Item Type Sales Channel Order Priority  \
# 75  North America    Mexico      Household       Offline              C
# 85  North America    Mexico  Personal Care       Offline              L
# 96           Asia  Malaysia         Fruits       Offline              L
# 98  North America    Mexico  Personal Care       Offline              M
#
#     Order Date   Order ID   Ship Date  Units Sold  Unit Price  Unit Cost  \
# 75   11/6/2014  986435210  12/12/2014        6954      668.27     502.54
# 85   2/17/2012  430915820   3/20/2012        6422       81.73      56.67
# 96  11/11/2011  810711038  12/28/2011        6267        9.33       6.92
# 98   7/30/2015  559427106    8/8/2015        5767       81.73      56.67
#
#     Total Revenue  Total Cost  Total Profit
# 75     4647149.58  3494663.16    1152486.42
# 85      524870.06   363934.74     160935.32
# 96       58471.11    43367.64      15103.47
# 98      471336.91   326815.89     144521.02

# %% [markdown]
# ### Bu davlatlar mavjuda bo'lganligi sababli ular haqidagi barcha ma'lumotlarni bizga chiqarib berdi

# %% [markdown]
# ### Endi loc dan foydalanib ko'rmoqchiman

# %%
ndf = df.set_index('Country') # locdan foydalanish uchun set_index() funksiyasidan foydalandim
ndf.loc[['Russia', 'Malaysia', 'Albania']]
# Out:
#           Region        Item Type Sales Channel Order Priority  Order Date  \
# Country
# Russia    Europe  Office Supplies       Offline              L    5/2/2014
# Malaysia    Asia           Fruits       Offline              L  11/11/2011
# Albania   Europe          Clothes        Online              C    2/2/2010
#
#            Order ID   Ship Date  Units Sold  Unit Price  Unit Cost  \
# Country
# Russia    341417157    5/8/2014        1779      651.21     524.96
# Malaysia  810711038  12/28/2011        6267        9.33       6.92
# Albania   385383069   3/18/2010        2269      109.28      35.84
#
#           Total Revenue  Total Cost  Total Profit
# Country
# Russia       1158502.59   933903.84     224598.75
# Malaysia       58471.11    43367.64      15103.47
# Albania       247956.32    81320.96     166635.36

# %% [markdown]
# ### Ko'rib turganimizdek bir nechta davlatlarni loc ichiga list shaklida berib ularning ma'lumotlarini chiqarib oldik

# %% [markdown]
# ### Endigi navbatda loc dan ham qatorlar hamda ustunlar uchun foydalanib ko'ramiz

# %%
df.loc[0:10, ['Region', 'Item Type']]
# Out:
#                                Region        Item Type
# 0               Australia and Oceania        Baby Food
# 1   Central America and the Caribbean           Cereal
# 2                              Europe  Office Supplies
# 3                  Sub-Saharan Africa           Fruits
# 4                  Sub-Saharan Africa  Office Supplies
# 5               Australia and Oceania        Baby Food
# 6                  Sub-Saharan Africa        Household
# 7                  Sub-Saharan Africa       Vegetables
# 8                  Sub-Saharan Africa    Personal Care
# 9                  Sub-Saharan Africa           Cereal
# 10                               Asia       Vegetables

# %% [markdown]
# ### locning ichiga shunday shart yozdim: 0 dan 10gacha bo'lgan indeksdagi va ustunlari nomi 'Region' va 'Item Type' bo'lganlarini chiqar

# %%
# df['Country'].isin(['Malaysia']).head(10)  # - locdan foydalanib ko'rdim True Falseni ko'rish uchun

# %% [markdown]
# ### Indexlar bo'yicha sortlaydigan metod bilan tanishamiz

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %% [markdown]
# ### Alifbo bo'lsa ham sortlashimiz mumkin lekin index uchun bir raqamlar bilan to'ldirilgan ustunni tanlab olmoqchiman

# %%
xs_df = df.drop_duplicates(subset='Unit Price')
new_xsdf = xs_df.set_index('Unit Price').sort_index()

# %% [markdown]
# ### 'Unit Price' ustunidagi duplikatlardan qutulib oldim keyin esa shu ustunni index qilib dataramega o'rnatdim va indexi bo'yicha sortlab chiqardim

# %% [markdown]
# ### Endigi davbat sort_index() metodini argumentlar bergan holda ishlatib ko'ramiz

# %% [markdown]
# ### Nusxalangan dataframe new_xsdf ni teskari tartibda indeksi bo'yicha sortlab kordim

# %%
new_xsdf.sort_index(ascending=False)
# Out:
#                                        Region                Country  \
# Unit Price
# 668.27                     Sub-Saharan Africa                 Angola
# 651.21                                 Europe                 Russia
# 437.20                                   Asia              Sri Lanka
# 421.89                  Australia and Oceania             East Timor
# 255.28                  Australia and Oceania                 Tuvalu
# 205.70      Central America and the Caribbean                Grenada
# 154.06                     Sub-Saharan Africa           Burkina Faso
# 152.58      Central America and the Caribbean               Honduras
# 109.28                     Sub-Saharan Africa             Cape Verde
# 81.73                      Sub-Saharan Africa  Republic of the Congo
# 47.45                      Sub-Saharan Africa               Cameroon
# 9.33                       Sub-Saharan Africa  Sao Tome and Principe
#
# ...

# %% [markdown]
# ### Slicing usulidan foydalanib ko'ramiz

# %% [markdown]
# ### 'Country' ustunini index qilib olmoqchiman va keyin locdan foydalangan holda biror davlatdan biror davlatgacha slicing usulida chiqarmoqchiman

# %%
ddf = df.set_index('Country')
ddf
# Out:
#                                                   Region        Item Type  \
# Country
# Tuvalu                             Australia and Oceania        Baby Food
# Grenada                Central America and the Caribbean           Cereal
# Russia                                            Europe  Office Supplies
# Sao Tome and Principe                 Sub-Saharan Africa           Fruits
# Rwanda                                Sub-Saharan Africa  Office Supplies
# ...                                                  ...              ...
# Mali                                  Sub-Saharan Africa          Clothes
# Malaysia                                            Asia           Fruits
# Sierra Leone                          Sub-Saharan Africa       Vegetables
# Mexico                                     North America    Personal Care
# Mozambique                            Sub-Saharan Africa        Household
#
# ...

# %%
ddf.loc['Tuvalu':'Mozambique']
# Out:
#                                                   Region        Item Type  \
# Country
# Tuvalu                             Australia and Oceania        Baby Food
# Grenada                Central America and the Caribbean           Cereal
# Russia                                            Europe  Office Supplies
# Sao Tome and Principe                 Sub-Saharan Africa           Fruits
# Rwanda                                Sub-Saharan Africa  Office Supplies
# ...                                                  ...              ...
# Mali                                  Sub-Saharan Africa          Clothes
# Malaysia                                            Asia           Fruits
# Sierra Leone                          Sub-Saharan Africa       Vegetables
# Mexico                                     North America    Personal Care
# Mozambique                            Sub-Saharan Africa        Household
#
# ...

# %% [markdown]
# ### Natija chiqdi lekin biz bergan index qiymatlari yagona bo'lmasa yani takrorlagan bo'lsa xatolik beradi

# %% [markdown]
# ### Biz slicingdan ustunlar uchun ham foydalanishimiz mumkin

# %%
ddf = ddf.loc[:, 'Region':'Order Date']

# %% [markdown]
# ### Natijada biz data framening birinchi 5ta ustunini chiqardik slicing yordamida

# %% [markdown]
# ### Keyin dataframe yanada ixchamroq korish uchun avvalgi sonli indekslarini reset_index() metodi yordamida ortga qaytardim va birinchi 15 ta qatorni head() metodi yordamida chiqarib oldim

# %%
for_pivot = ddf.reset_index().head(15)
for_pivot
# Out:
#                   Country                             Region        Item Type  \
# 0                  Tuvalu              Australia and Oceania        Baby Food
# 1                 Grenada  Central America and the Caribbean           Cereal
# 2                  Russia                             Europe  Office Supplies
# 3   Sao Tome and Principe                 Sub-Saharan Africa           Fruits
# 4                  Rwanda                 Sub-Saharan Africa  Office Supplies
# 5         Solomon Islands              Australia and Oceania        Baby Food
# 6                  Angola                 Sub-Saharan Africa        Household
# 7            Burkina Faso                 Sub-Saharan Africa       Vegetables
# 8   Republic of the Congo                 Sub-Saharan Africa    Personal Care
# 9                 Senegal                 Sub-Saharan Africa           Cereal
# 10             Kyrgyzstan                               Asia       Vegetables
# ...

# %% [markdown]
# ### iloc dan foydalanib head funksiyasiga taqlid qilamiz:
# ### Izoh: loc dan biz label-based indexing uchun foydalanamiz, iloc dan esa integer-based indexing uchun foydalanamiz va bu pandas kutubxonasining maxsus qurilmasi bo'lgani uchun biz buni funksiya deyshimiz va funksiya belgisini qoyishimiz xato '()' funksiya lekin biz o'ylagan funksiya emas. Bu maxsus pandas kutubxonasining funksiyasi

# %%
ddf.iloc[0:5]
# Out:
#                                                   Region        Item Type  \
# Country
# Tuvalu                             Australia and Oceania        Baby Food
# Grenada                Central America and the Caribbean           Cereal
# Russia                                            Europe  Office Supplies
# Sao Tome and Principe                 Sub-Saharan Africa           Fruits
# Rwanda                                Sub-Saharan Africa  Office Supplies
#
#                       Sales Channel Order Priority Order Date
# Country
# Tuvalu                      Offline              H  5/28/2010
# Grenada                      Online              C  8/22/2012
# Russia                      Offline              L   5/2/2014
# Sao Tome and Principe        Online              C  6/20/2014
# Rwanda                      Offline              L   2/1/2013

# %% [markdown]
# ### Natija head() funksiyasining default holatidagidek natija qaytardi

# %% [markdown]
# ### Pivot_table() dan foydalanamiz

# %%
data = {
    'A': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'],
    'B': ['one', 'one', 'two', 'two', 'one', 'one'],
    'C': [1, 3, 2, 5, 4, 6],
    'D': [10, 20, 30, 40, 50, 60]
}

df_pivot = pd.DataFrame(data)
df_pivot
# Out:
#      A    B  C   D
# 0  foo  one  1  10
# 1  foo  one  3  20
# 2  foo  two  2  30
# 3  bar  two  5  40
# 4  bar  one  4  50
# 5  bar  one  6  60

# %%
df_pivot.pivot_table(values='D', index=['A', 'B'], aggfunc=['sum', 'mean'])
# Out:
#          sum  mean
#            D     D
# A   B
# bar one  110  55.0
#     two   40  40.0
# foo one   30  15.0
#     two   30  30.0
